# %%
import geopy.distance
import pandas as pd
# Create a new dataframe with Lat, Long, and place columns
df = pd.DataFrame({'Lat': [], 'Long': [], 'Place': []})
# Baca dataset
df2 = pd.read_csv('coordinate.csv', delimiter=';')
selected_indices = [11, 8, 9, 40, 17, 39, 14, 15, 33]
df2 = df2.loc[selected_indices]
# Add user-defined latitude and longitude
user_lat = -8.652933
user_long = 114.678

# Add data to the dataframe
df.loc[0] = [user_lat, user_long, place]

# Print the dataframe
df
df2.loc[0] = [user_lat, user_long, 'User Location']
df2
# Out:
#          Lat        Long                           Place
# 11 -8.154706  114.522143             Pantai Teluk Terima
# 8  -8.274783  114.512565              Pantai Candikusuma
# 9  -8.342441  114.539393                 Pantai Pebuahan
# 40 -8.255748  114.616127                 Bendungan Benel
# 17 -8.332533  114.639715        Air Terjun Kayangan Sawe
# 39 -8.273424  114.662254  Wisata Puncak JR Jembrana Bali
# 14 -8.270016  114.687419            Air Terjun Yeh Mesee
# 15 -8.354902  114.705309             Sidi Tapa Waterfall
# 33 -8.339134  114.750361             Air Terjun Yeh Buah
# 0  -8.652933  114.678000                   User Location

# %%
# Fungsi untuk mendapatkan matriks jarak menggunakan geopy
def get_distance_matrix(df):
    distances = {}
    for i, place1 in df.iterrows():
        coords_1 = (place1['Lat'], place1['Long'])
        for j, place2 in df.iterrows():
            if i != j:
                coords_2 = (place2['Lat'], place2['Long'])
                distance = geopy.distance.geodesic(coords_1, coords_2).km
                distances[(place1['Place'], place2['Place'])] = distance
    return distances

# Panggil fungsi untuk mendapatkan matriks jarak
distances = get_distance_matrix(df2)

# Print hasil jarak antar tempat wisata
for (place1, place2), distance in distances.items():
    print(f"Jarak dari {place1} ke {place2}: {distance:.2f} km")
# Out:
# Jarak dari Pantai Teluk Terima ke Pantai Candikusuma: 13.32 km
# Jarak dari Pantai Teluk Terima ke Pantai Pebuahan: 20.85 km
# Jarak dari Pantai Teluk Terima ke Bendungan Benel: 15.24 km
# Jarak dari Pantai Teluk Terima ke Air Terjun Kayangan Sawe: 23.55 km
# Jarak dari Pantai Teluk Terima ke Wisata Puncak JR Jembrana Bali: 20.27 km
# Jarak dari Pantai Teluk Terima ke Air Terjun Yeh Mesee: 22.23 km
# Jarak dari Pantai Teluk Terima ke Sidi Tapa Waterfall: 29.96 km
# Jarak dari Pantai Teluk Terima ke Air Terjun Yeh Buah: 32.38 km
# Jarak dari Pantai Teluk Terima ke User Location: 57.71 km
# Jarak dari Pantai Candikusuma ke Pantai Teluk Terima: 13.32 km
# Jarak dari Pantai Candikusuma ke Pantai Pebuahan: 8.05 km
# Jarak dari Pantai Candikusuma ke Bendungan Benel: 11.60 km
# Jarak dari Pantai Candikusuma ke Air Terjun Kayangan Sawe: 15.39 km
# Jarak dari Pantai Candikusuma ke Wisata Puncak JR Jembrana Bali: 16.49 km
# Jarak dari Pantai Candikusuma ke Air Terjun Yeh Mesee: 19.27 km
# Jarak dari Pantai Candikusuma ke Sidi Tapa Waterfall: 23.01 km
# Jarak dari Pantai Candikusuma ke Air Terjun Yeh Buah: 27.15 km
# Jarak dari Pantai Candikusuma ke User Location: 45.62 km
# Jarak dari Pantai Pebuahan ke Pantai Teluk Terima: 20.85 km
# Jarak dari Pantai Pebuahan ke Pantai Candikusuma: 8.05 km
# Jarak dari Pantai Pebuahan ke Bendungan Benel: 12.78 km
# Jarak dari Pantai Pebuahan ke Air Terjun Kayangan Sawe: 11.10 km
# Jarak dari Pantai Pebuahan ke Wisata Puncak JR Jembrana Bali: 15.54 km
# Jarak dari Pantai Pebuahan ke Air Terjun Yeh Mesee: 18.17 km
# Jarak dari Pantai Pebuahan ke Sidi Tapa Waterfall: 18.33 km
# Jarak dari Pantai Pebuahan ke Air Terjun Yeh Buah: 23.24 km
# Jarak dari Pantai Pebuahan ke User Location: 37.58 km
# Jarak dari Bendungan Benel ke Pantai Teluk Terima: 15.24 km
# Jarak dari Bendungan Benel ke Pantai Candikusuma: 11.60 km
# Jarak dari Bendungan Benel ke Pantai Pebuahan: 12.78 km
# Jarak dari Bendungan Benel ke Air Terjun Kayangan Sawe: 8.88 km
# Jarak dari Bendungan Benel ke Wisata Puncak JR Jembrana Bali: 5.44 km
# Jarak dari Bendungan Benel ke Air Terjun Yeh Mesee: 8.01 km
# Jarak dari Bendungan Benel ke Sidi Tapa Waterfall: 14.72 km
# Jarak dari Bendungan Benel ke Air Terjun Yeh Buah: 17.43 km
# Jarak dari Bendungan Benel ke User Location: 44.45 km
# Jarak dari Air Terjun Kayangan Sawe ke Pantai Teluk Terima: 23.55 km
# Jarak dari Air Terjun Kayangan Sawe ke Pantai Candikusuma: 15.39 km
# Jarak dari Air Terjun Kayangan Sawe ke Pantai Pebuahan: 11.10 km
# Jarak dari Air Terjun Kayangan Sawe ke Bendungan Benel: 8.88 km
# Jarak dari Air Terjun Kayangan Sawe ke Wisata Puncak JR Jembrana Bali: 6.99 km
# Jarak dari Air Terjun Kayangan Sawe ke Air Terjun Yeh Mesee: 8.68 km
# Jarak dari Air Terjun Kayangan Sawe ke Sidi Tapa Waterfall: 7.64 km
# Jarak dari Air Terjun Kayangan Sawe ke Air Terjun Yeh Buah: 12.21 km
# Jarak dari Air Terjun Kayangan Sawe ke User Location: 35.69 km
# Jarak dari Wisata Puncak JR Jembrana Bali ke Pantai Teluk Terima: 20.27 km
# Jarak dari Wisata Puncak JR Jembrana Bali ke Pantai Candikusuma: 16.49 km
# Jarak dari Wisata Puncak JR Jembrana Bali ke Pantai Pebuahan: 15.54 km
# Jarak dari Wisata Puncak JR Jembrana Bali ke Bendungan Benel: 5.44 km
# Jarak dari Wisata Puncak JR Jembrana Bali ke Air Terjun Kayangan Sawe: 6.99 km
# Jarak dari Wisata Puncak JR Jembrana Bali ke Air Terjun Yeh Mesee: 2.80 km
# Jarak dari Wisata Puncak JR Jembrana Bali ke Sidi Tapa Waterfall: 10.18 km
# Jarak dari Wisata Puncak JR Jembrana Bali ke Air Terjun Yeh Buah: 12.13 km
# Jarak dari Wisata Puncak JR Jembrana Bali ke User Location: 42.01 km
# Jarak dari Air Terjun Yeh Mesee ke Pantai Teluk Terima: 22.23 km
# Jarak dari Air Terjun Yeh Mesee ke Pantai Candikusuma: 19.27 km
# Jarak dari Air Terjun Yeh Mesee ke Pantai Pebuahan: 18.17 km
# Jarak dari Air Terjun Yeh Mesee ke Bendungan Benel: 8.01 km
# Jarak dari Air Terjun Yeh Mesee ke Air Terjun Kayangan Sawe: 8.68 km
# Jarak dari Air Terjun Yeh Mesee ke Wisata Puncak JR Jembrana Bali: 2.80 km
# Jarak dari Air Terjun Yeh Mesee ke Sidi Tapa Waterfall: 9.59 km
# Jarak dari Air Terjun Yeh Mesee ke Air Terjun Yeh Buah: 10.32 km
# Jarak dari Air Terjun Yeh Mesee ke User Location: 42.36 km
# Jarak dari Sidi Tapa Waterfall ke Pantai Teluk Terima: 29.96 km
# Jarak dari Sidi Tapa Waterfall ke Pantai Candikusuma: 23.01 km
# Jarak dari Sidi Tapa Waterfall ke Pantai Pebuahan: 18.33 km
# Jarak dari Sidi Tapa Waterfall ke Bendungan Benel: 14.72 km
# Jarak dari Sidi Tapa Waterfall ke Air Terjun Kayangan Sawe: 7.64 km
# Jarak dari Sidi Tapa Waterfall ke Wisata Puncak JR Jembrana Bali: 10.18 km
# Jarak dari Sidi Tapa Waterfall ke Air Terjun Yeh Mesee: 9.59 km
# Jarak dari Sidi Tapa Waterfall ke Air Terjun Yeh Buah: 5.26 km
# Jarak dari Sidi Tapa Waterfall ke User Location: 33.10 km
# Jarak dari Air Terjun Yeh Buah ke Pantai Teluk Terima: 32.38 km
# Jarak dari Air Terjun Yeh Buah ke Pantai Candikusuma: 27.15 km
# Jarak dari Air Terjun Yeh Buah ke Pantai Pebuahan: 23.24 km
# Jarak dari Air Terjun Yeh Buah ke Bendungan Benel: 17.43 km
# Jarak dari Air Terjun Yeh Buah ke Air Terjun Kayangan Sawe: 12.21 km
# Jarak dari Air Terjun Yeh Buah ke Wisata Puncak JR Jembrana Bali: 12.13 km
# Jarak dari Air Terjun Yeh Buah ke Air Terjun Yeh Mesee: 10.32 km
# Jarak dari Air Terjun Yeh Buah ke Sidi Tapa Waterfall: 5.26 km
# Jarak dari Air Terjun Yeh Buah ke User Location: 35.61 km
# Jarak dari User Location ke Pantai Teluk Terima: 57.71 km
# Jarak dari User Location ke Pantai Candikusuma: 45.62 km
# Jarak dari User Location ke Pantai Pebuahan: 37.58 km
# Jarak dari User Location ke Bendungan Benel: 44.45 km
# Jarak dari User Location ke Air Terjun Kayangan Sawe: 35.69 km
# Jarak dari User Location ke Wisata Puncak JR Jembrana Bali: 42.01 km
# Jarak dari User Location ke Air Terjun Yeh Mesee: 42.36 km
# Jarak dari User Location ke Sidi Tapa Waterfall: 33.10 km
# Jarak dari User Location ke Air Terjun Yeh Buah: 35.61 km

# %%
import networkx as nx
from networkx.algorithms.approximation import traveling_salesman_problem

# Buat graf dengan jarak sebagai bobot
G = nx.Graph()
for (place1, place2), distance in distances.items():
    G.add_edge(place1, place2, weight=distance)

# TSP dengan algoritma Nearest Neighbor
route = traveling_salesman_problem(G, weight='weight')
print("Rute terbaik: ", route)
# Out:
# Rute terbaik:  ['Pantai Teluk Terima', 'Bendungan Benel', 'Wisata Puncak JR Jembrana Bali', 'Air Terjun Yeh Mesee', 'Air Terjun Kayangan Sawe', 'User Location', 'Sidi Tapa Waterfall', 'Air Terjun Yeh Buah', 'Pantai Pebuahan', 'Pantai Candikusuma', 'Pantai Teluk Terima']

# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.algorithms.approximation import traveling_salesman_problem

# Buat graf dengan jarak sebagai bobot
G = nx.Graph()
for (place1, place2), distance in distances.items():
    G.add_edge(place1, place2, weight=distance)

# TSP dengan algoritma Nearest Neighbor
route = traveling_salesman_problem(G, weight='weight')
print("Rute terbaik: ", route)

# Fungsi untuk mengekstrak koordinat dari dataset
def get_coordinates(place, df):
    row = df[df['Place'] == place]
    if not row.empty:
        return (row.iloc[0]['Lat'], row.iloc[0]['Long'])
    else:
        return None

# Dapatkan koordinat untuk setiap tempat di rute
route_coords = [get_coordinates(place, df2) for place in route]

# Buat plot
plt.figure(figsize=(12, 8))

# Tambahkan edges ke plot
for i in range(len(route_coords) - 1):
    x_values = [route_coords[i][1], route_coords[i+1][1]]
    y_values = [route_coords[i][0], route_coords[i+1][0]]
    plt.plot(x_values, y_values, 'bo-')  # 'bo-' menggambarkan titik biru dengan garis solid

# Tambahkan edge dari tempat terakhir ke tempat pertama untuk menutup rute
x_values = [route_coords[-1][1], route_coords[0][1]]
y_values = [route_coords[-1][0], route_coords[0][0]]
plt.plot(x_values, y_values, 'bo-')

# Tambahkan nama tempat ke plot
for place, (lat, long) in zip(route, route_coords):
    plt.text(long, lat, place, fontsize=9)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Rute Terbaik untuk Itinerary')
plt.grid()
plt.show()
# Out:
# Rute terbaik:  ['Pantai Teluk Terima', 'Bendungan Benel', 'Wisata Puncak JR Jembrana Bali', 'Air Terjun Yeh Mesee', 'Air Terjun Kayangan Sawe', 'User Location', 'Sidi Tapa Waterfall', 'Air Terjun Yeh Buah', 'Pantai Pebuahan', 'Pantai Candikusuma', 'Pantai Teluk Terima']
