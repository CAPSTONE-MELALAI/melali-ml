# %%
import pandas as pd
import numpy as np

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('new_bali_dataset.csv', delimiter=';')
df.head()
# Out:
#    index                              place  \
# 0      0         Pura Puseh Desa Adat Kutri
# 1      1                 Pura Dalem Begawan
# 2      2     D'tukad Desa Budaya Kertalangu
# 3      3                  Desa Adat Cangkup
# 4      4  Monumen Perjuangan Desa Tegaljadi
#
#                                                  url  is_accessibility  \
# 0  https://www.google.com/maps/place/Pura+Puseh+D...                 0
# 1  https://www.google.com/maps/place/Pura+Dalem+B...                 0
# 2  https://www.google.com/maps/place/D'tukad+Desa...                 0
# 3  https://www.google.com/maps/place/Desa+Adat+Ca...                 0
# 4  https://www.google.com/maps/place/Monumen+Perj...                 0
#
#    rating  n_reviews                                            address  \
# 0     3.0          1  F863+W53, Buruan, Kec. Blahbatuh, Kabupaten Gi...
# 1     3.0          2  8682+87P, Dauh Puri Kauh, Kec. Denpasar Bar., ...
# 2     3.6          9  9744+WJQ, Kesiman Kertalangu, Kec. Denpasar Ti...
# 3     3.7          3  Pupuan Sawah, Kec. Selemadeg, Kabupaten Tabana...
# 4     4.0          1  G585+J3, Tegaljadi, Kec. Marga, Kabupaten Taba...
#
#    price  idx_category category  \
# 0  15000             0  Sejarah
# 1  15000             0  Sejarah
# 2  20000             0  Sejarah
# 3  15000             0  Sejarah
# 4  15000             0  Sejarah
#
#                                          description       lat        long  \
# 0  Pura Puseh is one of the oldest temples in Bal... -8.514987  115.298791
# 1  Located near the Petanu River, Pura Dalem Bega... -8.682596  115.200610
# 2  D'tukad Desa Budaya Kertalangu is a cultural t... -8.639347  115.257474
# 3  Desa Adat Cangkup is a traditional village tha... -8.439189  115.051934
# 4  This monument was erected to commemorate the s... -8.483242  115.157706
#
#                                Coordinate Is_accessibility
# 0  -8.514986706754593, 115.29879103124946            False
# 1  -8.682595632877103, 115.20061015733499            False
# 2  -8.639347199121982, 115.25747408289917            False
# 3   -8.43918883821229, 115.05193408611053            False
# 4    -8.4832418767373, 115.15770565767143            False

# %%
df.shape
# Out:
# (195, 15)

# %% [markdown]
# # Preproses

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             195 non-null    int64
#  1   place             195 non-null    object
#  2   url               195 non-null    object
#  3   is_accessibility  195 non-null    int64
#  4   rating            195 non-null    float64
#  5   n_reviews         195 non-null    int64
#  6   address           195 non-null    object
#  7   price             195 non-null    int64
#  8   idx_category      195 non-null    int64
#  9   category          195 non-null    object
#  10  description       195 non-null    object
#  11  lat               163 non-null    float64
#  12  long              163 non-null    float64
#  13  Coordinate        163 non-null    object
#  14  Is_accessibility  163 non-null    object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 23.0+ KB

# %%
df['price'].fillna(0, inplace=True)
df['category'].fillna('unknown', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             195 non-null    int64
#  1   place             195 non-null    object
#  2   url               195 non-null    object
#  3   is_accessibility  195 non-null    int64
#  4   rating            195 non-null    float64
#  5   n_reviews         195 non-null    int64
#  6   address           195 non-null    object
#  7   price             195 non-null    int64
#  8   idx_category      195 non-null    int64
#  9   category          195 non-null    object
#  10  description       195 non-null    object
#  11  lat               163 non-null    float64
#  12  long              163 non-null    float64
#  13  Coordinate        163 non-null    object
#  14  Is_accessibility  163 non-null    object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 23.0+ KB

# %%
# Function for removing NonAscii characters
def _removeNonAscii(text):
    return "".join(i for i in text if  ord(i)<128)

# Function for converting into lower case
def make_lower_case(text):
    return text.lower()

# Function for removing stop words
def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

# Function for removing punctuation
def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text

# Function for removing the html tags
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

# Applying all the functions in description and storing as a cleaned_desc
df['cleaned_desc'] = df['description'].apply(_removeNonAscii)
df['cleaned_desc'] = df.cleaned_desc.apply(func = make_lower_case)
df['cleaned_desc'] = df.cleaned_desc.apply(func = remove_stop_words)
df['cleaned_desc'] = df.cleaned_desc.apply(func=remove_punctuation)
df['cleaned_desc'] = df.cleaned_desc.apply(func=remove_html)

# %% [markdown]
# # Recommendation

# %%
def recommendation(index):
    
    place = df.loc[index, 'place']
    category = df.loc[index, 'category']
    # Matching the category with the dataset and reset the index
    data_category = df[df['category'] == category].reset_index(drop=True)
  
    # Convert the index into series
    indices = pd.Series(data_category.index, index=data_category['place'])
    
    # Converting the place description into vectors
    tf = TfidfVectorizer(analyzer='word', ngram_range=(2, 2), min_df=1, stop_words='english')
    tfidf_matrix = tf.fit_transform(data_category['cleaned_desc'])
    
    # Calculating the similarity measures based on Cosine Similarity
    cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
    
    # Get the index corresponding to the place
    idx = indices[place]
    
    # Get the pairwise similarity scores 
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the places
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Scores of the 5 most similar places
    sim_scores = sim_scores[1:10]
    
    # Place indices
    place_indices = [i[0] for i in sim_scores]
   
    # Top 5 place recommendations
    records = data_category['place'].iloc[place_indices]
    return records

# %%
recommendation(160)
# Out:
# 5      Pura Dalem Desa Adat Negara Batuan
# 2                Pura Jagatnatha Jembrana
# 0                      Pura Luhur Srijong
# 1                           Pura Perancak
# 3    Nista mandala pura luhur rambut siwi
# 4                        Pura Geger Beach
# Name: place, dtype: object

# %%
recommendation(160)
# Out:
# 5      Pura Dalem Desa Adat Negara Batuan
# 2                Pura Jagatnatha Jembrana
# 0                      Pura Luhur Srijong
# 1                           Pura Perancak
# 3    Nista mandala pura luhur rambut siwi
# 4                        Pura Geger Beach
# Name: place, dtype: object

# %%
def sort_place(affordable_places,lat_user, long_user):
    # get latitude and longitude from affordable_places

    # calculate euclidean distance from user to places
    distances = np.sqrt(((affordable_places['lat'] - lat_user)**2) + ((affordable_places['long'] - long_user)**2))
    affordable_places['distance'] = distances
    
    # sort dataframe based on distance
    affordable_places = affordable_places.sort_values(by='distance', ascending=False)
    
    return affordable_places

# %%
def create_recommendation(idx_selected, budget, days, lat_user, long_user, is_accessibility=0):
    # create recommendation
    recommended_places = set()
    # selected_places = df.iloc[idx_selected][['place', 'category']].values
    for idx in idx_selected:
        recommended_places.update(recommendation(idx))

    filtered_places = df[df['place'].isin(recommended_places)]
    
    # filter based on accessibility
    if is_accessibility == 1:
        filtered_places = filtered_places[filtered_places['is_accessibility'] == 1]
   
    #filter based on budget
    affordable_places = filtered_places[filtered_places['price'] <= budget / days]

    # Sort places by Google Maps Rating and then by Review Count
    affordable_places = affordable_places.sort_values(by=['rating', 'n_reviews'], ascending=[False, False])
    # return affordable_places
    # sort by distance
    affordable_places = sort_place(affordable_places, lat_user, long_user)

    # Create itinerary
    itinerary = {}
    list_of_dest = []
    total_cost = 0
    places_per_day = 3
    all_places = filtered_places.sort_values(by=['rating', 'n_reviews'], ascending=[False, False])

    used_places = set()
    for day in range(1, days + 1):
        daily_itinerary = affordable_places[~affordable_places['place'].isin(used_places)].head(places_per_day)
        
        # Fallback if no affordable places are left
        if daily_itinerary.empty:
            daily_itinerary = all_places[~all_places['place'].isin(used_places)].head(places_per_day)
        
        # Ensure at least one place per day
        while len(daily_itinerary) < places_per_day and not all_places[~all_places['place'].isin(used_places)].empty:
            additional_place = all_places[~all_places['place'].isin(used_places)].head(1)
            daily_itinerary = pd.concat([daily_itinerary, additional_place])
        
        for row in daily_itinerary.iterrows():
            dest_dict = {}
            dest_dict['place'] = row[1]['place']
            dest_dict['url'] = row[1]['url']
            dest_dict['address'] = row[1]['address']
            dest_dict['is_accessibility'] = row[1]['is_accessibility']
            dest_dict['rating'] = row[1]['rating']
            dest_dict['n_reviews'] = row[1]['n_reviews']
            dest_dict['price'] = row[1]['price']
            dest_dict['category'] = row[1]['category']
            dest_dict['description'] = row[1]['description']
            list_of_dest.append(dest_dict)
            
        # itinerary[f'Day {day}'] = {
        #     'place' : daily_itinerary['place'].tolist(),
        #     'url' : daily_itinerary['url'].tolist(),
        #     'is_accessibility' : daily_itinerary['is_accessibility'].tolist(),
        #     'rating' : daily_itinerary['rating'].tolist(),
        #     'n_reviews' : daily_itinerary['n_reviews'].tolist(),
        #     'address' : daily_itinerary['address'].tolist(),
        #     'price' : daily_itinerary['price'].tolist(),
        #     'category' : daily_itinerary['category'].tolist(),
        #     'description' : daily_itinerary['description'].tolist(),
        #     'lat' : daily_itinerary['lat'].tolist(),
        #     'long' : daily_itinerary['long'].tolist()
        # }
        # print(list_of_dest)
        # itinerary[f'Day {day}'] = daily_itinerary['place'].tolist()
        itinerary[f'Day {day}'] = list_of_dest
        daily_cost = daily_itinerary['price'].sum()
        total_cost += daily_cost
        
        # Remove selected places from affordable_places and all_places to avoid duplicates
        used_places.update(daily_itinerary['place'])

    #     print(f"Jadwal Hari {day} :")
    #     for i, place in enumerate(daily_itinerary['place'], 1):
    #         print(f"{i}. {place}")
    #     print(f"Biaya yang dikeluarkan untuk hari {day} : Rp {daily_cost}\n")
    
    # print(f"Total biaya yang dikeluarkan selama {days} hari : Rp {total_cost}\n")
    return itinerary

# %%
### TRY TO IMPLEMENT THE RECOMMENDATION SYSTEM HERE ###
idx_selected = [80,21,24]
budget = 100_000
days = 3
lat_user = -8.409518
long_user = 115.188919
is_accessibility = 0

get_recommendation = create_recommendation(idx_selected,budget, days, lat_user, long_user, is_accessibility)
get_recommendation
# Out:
# {'Day 1': [{'place': 'Pantai Teluk Terima',
#    'url': 'https://www.google.com/maps/place/Pantai+Karang+Sewu/@-8.154945,114.5221425,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd14275c7b4da25:0x63c1a19ef6d47c7d!8m2!3d-8.154945!4d114.5221425!16s%2Fg%2F11fx8bkzxl?entry=ttu',
#    'address': 'RGWC+2VC, Sumber Klampok, Kec. Gerokgak, Kabupaten Buleleng, Bali 81155',
#    'is_accessibility': 0,
#    'rating': 4.2,
#    'n_reviews': 124,
#    'price': 15000,
#    'category': 'Pantai',
#    'description': 'A tranquil and secluded beach in West Bali, Teluk Terima offers stunning ocean views and a peaceful atmosphere. This beach is ideal for snorkeling and diving with its clear water and beautiful coral reefs.'},
#   {'place': 'Pantai Candikusuma',
#    'url': 'https://www.google.com/maps/place/Pantai+Candikusuma/@-8.3080765,113.9412762,10z/data=!4m11!1m3!2m2!1stujuan+wisata+di+bali!6e1!3m6!1s0x2dd15e1bffae1d07:0x9a02e805abc254f8!8m2!3d-8.3080765!4d114.5180584!15sChV0dWp1YW4gd2lzYXRhIGRpIGJhbGlaFyIVdHVqdWFuIHdpc2F0YSBkaSBiYWxpkgESdG91cmlzdF9hdHRyYWN0aW9umgEjQ2haRFNVaE5NRzluUzBWSlEwRm5TVU5MWDJSWU5sbFJFQUXgAQA!16s%2Fg%2F11bx7g56hr?entry=ttu',
#    'address': 'Candikusuma, Kec. Melaya, Kabupaten Jembrana, Bali 82252',
#    'is_accessibility': 0,
#    'rating': 4.1,
#    'n_reviews': 298,
#    'price': 15000,
#    'category': 'Pantai',
#    'description': 'Candikusuma beach is black sand, located in Candikusuma village, Melaya District, Jembrana Regency - Bali.'},
#   {'place': 'Pantai Pebuahan',
#    'url': 'https://www.google.com/maps/place/Pantai+Pebuahan/@-8.3427596,114.5346719,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd1606edc4519df:0x7cb11caed1feef57!8m2!3d-8.3427649!4d114.5392853!16s%2Fg%2F11d_83wt47?entry=ttu',
#    'address': 'Banjar Pebuahan, Kecamatan Negara, Kabupaten Jembrana, Banyu Biru, Kec. Negara, Negara, Bali 81119',
#    'is_accessibility': 0,
#    'rating': 4.1,
#    'n_reviews': 311,
#    'price': 15000,
#    'category': 'Pantai',
#    'description': 'Pantai Pebuahan is a fishing beach with breathtaking views, often a docking place for traditional fishing boats. Visitors can enjoy stunning sunsets, observe local fishing activities, and experience an untouched beach atmosphere.'},
#   {'place': 'Bendungan Benel',
#    'url': 'https://www.google.com/maps/place/Bendungan+Benel/@-8.4656667,114.3373489,10z/data=!4m11!1m3!2m2!1stujuan+wisata+di+bali!6e1!3m6!1s0x2dd166b2f3170d0d:0x216029a7e98763ca!8m2!3d-8.2852077!4d114.6046845!15sChV0dWp1YW4gd2lzYXRhIGRpIGJhbGlaFyIVdHVqdWFuIHdpc2F0YSBkaSBiYWxpkgESdG91cmlzdF9hdHRyYWN0aW9umgEjQ2haRFNVaE5NRzluUzBWSlEwRm5TVU5YWnpSWVVtRm5FQUXgAQA!16s%2Fg%2F11b8_mpf94?entry=ttu',
#    'address': 'Benel, Berangbang, Kec. Negara, Kabupaten Jembrana, Bali 82218',
#    'is_accessibility': 0,
#    'rating': 4.4,
#    'n_reviews': 146,
#    'price': 15000,
#    'category': 'Wisata Alam',
#    'description': 'The dam serves as a source of irrigation and flood control, as well as being an attractive natural tourist destination. Visitors can enjoy views of the calm, green water and take a walk around the dam area, which is surrounded by lush nature.'},
#   {'place': 'Air Terjun Kayangan Sawe',
#    'url': 'https://www.google.com/maps/place/Air+Terjun+Kayangan+Sawe/@-8.3327987,114.6370431,17z/data=!3m1!4b1!4m6!3m5!1s0x2d
17z/data=!3m1!4b1!4m6!3m5!1s0x2dd14275c7b4da25:0x63c1a19ef6d47c7d!8m2!3d-8.154945!4d114.5221425!16s%2Fg%2F11fx8bkzxl?entry=ttu',
#    'address': 'RGWC+2VC, Sumber Klampok, Kec. Gerokgak, Kabupaten Buleleng, Bali 81155',
#    'is_accessibility': 0,
#    'rating': 4.2,
#    'n_reviews': 124,
#    'price': 15000,
#    'category': 'Pantai',
#    'description': 'A tranquil and secluded beach in West Bali, Teluk Terima offers stunning ocean views and a peaceful atmosphere. This beach is ideal for snorkeling and diving with its clear water and beautiful coral reefs.'},
#   {'place': 'Pantai Candikusuma',
#    'url': 'https://www.google.com/maps/place/Pantai+Candikusuma/@-8.3080765,113.9412762,10z/data=!4m11!1m3!2m2!1stujuan+wisata+di+bali!6e1!3m6!1s0x2dd15e1bffae1d07:0x9a02e805abc254f8!8m2!3d-8.3080765!4d114.5180584!15sChV0dWp1YW4gd2lzYXRhIGRpIGJhbGlaFyIVdHVqdWFuIHdpc2F0YSBkaSBiYWxpkgESdG91cmlzdF9hdHRyYWN0aW9umgEjQ2haRFNVaE5NRzluUzBWSlEwRm5TVU5MWDJSWU5sbFJFQUXgAQA!16s%2Fg%2F11bx7g56hr?entry=ttu',
#    'address': 'Candikusuma, Kec. Melaya, Kabupaten Jembrana, Bali 82252',
#    'is_accessibility': 0,
#    'rating': 4.1,
#    'n_reviews': 298,
#    'price': 15000,
#    'category': 'Pantai',
#    'description': 'Candikusuma beach is black sand, located in Candikusuma village, Melaya District, Jembrana Regency - Bali.'},
#   {'place': 'Pantai Pebuahan',
#    'url': 'https://www.google.com/maps/place/Pantai+Pebuahan/@-8.3427596,114.5346719,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd1606edc4519df:0x7cb11caed1feef57!8m2!3d-8.3427649!4d114.5392853!16s%2Fg%2F11d_83wt47?entry=ttu',
#    'address': 'Banjar Pebuahan, Kecamatan Negara, Kabupaten Jembrana, Banyu Biru, Kec. Negara, Negara, Bali 81119',
#    'is_accessibility': 0,
#    'rating': 4.1,
#    'n_reviews': 311,
#    'price': 15000,
#    'category': 'Pantai',
#    'description': 'Pantai Pebuahan is a fishing beach with breathtaking views, often a docking place for traditional fishing boats. Visitors can enjoy stunning sunsets, observe local fishing activities, and experience an untouched beach atmosphere.'},
#   {'place': 'Bendungan Benel',
#    'url': 'https://www.google.com/maps/place/Bendungan+Benel/@-8.4656667,114.3373489,10z/data=!4m11!1m3!2m2!1stujuan+wisata+di+bali!6e1!3m6!1s0x2dd166b2f3170d0d:0x216029a7e98763ca!8m2!3d-8.2852077!4d114.6046845!15sChV0dWp1YW4gd2lzYXRhIGRpIGJhbGlaFyIVdHVqdWFuIHdpc2F0YSBkaSBiYWxpkgESdG91cmlzdF9hdHRyYWN0aW9umgEjQ2haRFNVaE5NRzluUzBWSlEwRm5TVU5YWnpSWVVtRm5FQUXgAQA!16s%2Fg%2F11b8_mpf94?entry=ttu',
#    'address': 'Benel, Berangbang, Kec. Negara, Kabupaten Jembrana, Bali 82218',
#    'is_accessibility': 0,
#    'rating': 4.4,
#    'n_reviews': 146,
#    'price': 15000,
#    'category': 'Wisata Alam',
#    'description': 'The dam serves as a source of irrigation and flood control, as well as being an attractive natural tourist destination. Visitors can enjoy views of the calm, green water and take a walk around the dam area, which is surrounded by lush nature.'},
#   {'place': 'Air Terjun Kayangan Sawe',
#    'url': 'https://www.google.com/maps/place/Air+Terjun+Kayangan+Sawe/@-8.3327987,114.6370431,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd16237023f17dd:0xa50f0d676b0bac7c!8m2!3d-8.332804!4d114.639618!16s%2Fg%2F11dyb99s4n?entry=ttu',
#    'address': 'MJ8Q+VRH, Jl. Sawe Rangsasa, Dauhwaru, Kec. Jembrana, Kabupaten Jembrana, Bali 82218',
#    'is_accessibility': 0,
#    'rating': 4.3,
#    'n_reviews': 12,
#    'price': 15000,
#    'category': 'Wisata Alam',
#    'description': 

#    'price': 15000,
#    'category': 'Pantai',
#    'description': 'A tranquil and secluded beach in West Bali, Teluk Terima offers stunning ocean views and a peaceful atmosphere. This beach is ideal for snorkeling and diving with its clear water and beautiful coral reefs.'},
#   {'place': 'Pantai Candikusuma',
#    'url': 'https://www.google.com/maps/place/Pantai+Candikusuma/@-8.3080765,113.9412762,10z/data=!4m11!1m3!2m2!1stujuan+wisata+di+bali!6e1!3m6!1s0x2dd15e1bffae1d07:0x9a02e805abc254f8!8m2!3d-8.3080765!4d114.5180584!15sChV0dWp1YW4gd2lzYXRhIGRpIGJhbGlaFyIVdHVqdWFuIHdpc2F0YSBkaSBiYWxpkgESdG91cmlzdF9hdHRyYWN0aW9umgEjQ2haRFNVaE5NRzluUzBWSlEwRm5TVU5MWDJSWU5sbFJFQUXgAQA!16s%2Fg%2F11bx7g56hr?entry=ttu',
#    'address': 'Candikusuma, Kec. Melaya, Kabupaten Jembrana, Bali 82252',
#    'is_accessibility': 0,
#    'rating': 4.1,
#    'n_reviews': 298,
#    'price': 15000,
#    'category': 'Pantai',
#    'description': 'Candikusuma beach is black sand, located in Candikusuma village, Melaya District, Jembrana Regency - Bali.'},
#   {'place': 'Pantai Pebuahan',
#    'url': 'https://www.google.com/maps/place/Pantai+Pebuahan/@-8.3427596,114.5346719,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd1606edc4519df:0x7cb11caed1feef57!8m2!3d-8.3427649!4d114.5392853!16s%2Fg%2F11d_83wt47?entry=ttu',
#    'address': 'Banjar Pebuahan, Kecamatan Negara, Kabupaten Jembrana, Banyu Biru, Kec. Negara, Negara, Bali 81119',
#    'is_accessibility': 0,
#    'rating': 4.1,
#    'n_reviews': 311,
#    'price': 15000,
#    'category': 'Pantai',
#    'description': 'Pantai Pebuahan is a fishing beach with breathtaking views, often a docking place for traditional fishing boats. Visitors can enjoy stunning sunsets, observe local fishing activities, and experience an untouched beach atmosphere.'},
#   {'place': 'Bendungan Benel',
#    'url': 'https://www.google.com/maps/place/Bendungan+Benel/@-8.4656667,114.3373489,10z/data=!4m11!1m3!2m2!1stujuan+wisata+di+bali!6e1!3m6!1s0x2dd166b2f3170d0d:0x216029a7e98763ca!8m2!3d-8.2852077!4d114.6046845!15sChV0dWp1YW4gd2lzYXRhIGRpIGJhbGlaFyIVdHVqdWFuIHdpc2F0YSBkaSBiYWxpkgESdG91cmlzdF9hdHRyYWN0aW9umgEjQ2haRFNVaE5NRzluUzBWSlEwRm5TVU5YWnpSWVVtRm5FQUXgAQA!16s%2Fg%2F11b8_mpf94?entry=ttu',
#    'address': 'Benel, Berangbang, Kec. Negara, Kabupaten Jembrana, Bali 82218',
#    'is_accessibility': 0,
#    'rating': 4.4,
#    'n_reviews': 146,
#    'price': 15000,
#    'category': 'Wisata Alam',
#    'description': 'The dam serves as a source of irrigation and flood control, as well as being an attractive natural tourist destination. Visitors can enjoy views of the calm, green water and take a walk around the dam area, which is surrounded by lush nature.'},
#   {'place': 'Air Terjun Kayangan Sawe',
#    'url': 'https://www.google.com/maps/place/Air+Terjun+Kayangan+Sawe/@-8.3327987,114.6370431,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd16237023f17dd:0xa50f0d676b0bac7c!8m2!3d-8.332804!4d114.639618!16s%2Fg%2F11dyb99s4n?entry=ttu',
#    'address': 'MJ8Q+VRH, Jl. Sawe Rangsasa, Dauhwaru, Kec. Jembrana, Kabupaten Jembrana, Bali 82218',
#    'is_accessibility': 0,
#    'rating': 4.3,
#    'n_reviews': 12,
#    'price': 15000,
#    'category': 'Wisata Alam',
#    'description': 'This waterfall is located in a quiet and natural area, offering beautiful waterfall views with a natural pool below. Kayangan Sawe Waterfall is an ideal place to relax and swim in a cool and peaceful environment.'},
#   {'place': 'Wisata Puncak JR Jembrana Bali',
#    'url': 'https://www.google.com/maps/place/Wisata+Puncak+JR+Jembrana+Bali/@-8.3080765,113.9412762,10z/data=!4m11!1m3!2m2!1stujuan+wisata+di+bali!6e1!3m6!1s0x2dd1639df0ee229f:0xa6dfe9316341d2fc!8m2!3d-8.3011447!4d114.6617455!15sChV0dWp1YW4gd2lzYXRhIGRpIGJhbGmSARJ0b3VyaXN0X2F0dHJhY3Rpb27gAQA!16s%2Fg%2F11dx9982mb?entry=ttu',
#    'address': 'Banjar Pancaseming Desa Batuagung, Kecamatan Jembrana, Batuagung, Kec. Jembrana, Kabupaten Jembrana, Bali 82218',
#    'is_accessibility': 0,
#    'rating': 4.4,
#    'n_reviews': 125,
#    'price': 15000,
#    'category': 'Wisata Alam',
#    'description': "This place offers a bird's eye view with a beautiful panoramic view of nature. JR Peak is popular for trekking and enjoying sunrise or sunset views with a stunning backdrop of mountains and valleys."},
#   {'place': 'Air Terjun Yeh Mesee',
#    'url': 'https://www.google.com/maps/place/Air+Terjun+Yeh+Mesee/@-8.2702598,114.6848222,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd165a6f92dc13d:0x701a89789a94e25e!8m2!3d-8.2702651!4d114.6873971!16s%2Fg%2F11ghnyf29w?entry=ttu',
#    'address': 'PMHP+VXR, Pohsanten, Kec. Mendoyo, Kabupaten Jembrana, Bali 82261',
#    'is_accessibility': 0,
#    'rating': 4.3,
#    'n_reviews': 7,
#    'price': 15000,
#    'category': 'Wisata Alam',
#    'description': 'A waterfall located in an area not yet widely visited by tourists, Yeh Mesee offers beautiful waterfall views with a strong flow of water amidst lush tropical forests. This place is perfect for tourists seeking tranquility and pure natural beauty.'},
#   {'place': 'Sidi Tapa Waterfall',
#    'url': 'https://www.google.com/maps/place/Sidi+Tapa+Waterfall/@-8.3551145,114.702788,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd1634010b78511:0x6d4495462805230d!8m2!3d-8.3551198!4d114.7053629!16s%2Fg%2F11p788h39_?entry=ttu',
#    'address': 'JPV4+X45, Tegal Cangkring, Kec. Mendoyo, Kabupaten Jembrana, Bali 82261',
#    'is_accessibility': 0,
#    'rating': 4.3,
#    'n_reviews': 8,
#    'price': 15000,
#    'category': 'Wisata Alam',
#    'description': "This hidden waterfall in Buleleng offers breathtaking natural beauty with water flowing strongly between rocks and green vegetation. The location is often visited by nature lovers and adventurers who want to enjoy Bali's unexplored natural beauty."},
#   {'place': 'Air Terjun Yeh Buah',
#    'url': 'https://www.google.com/maps/place/Air+Terjun+Yeh+Buah/@-8.3393832,114.747829,17z/data=!4m15!1m8!3m7!1s0x2dd17d7298ec6a85:0xa2feca286660c8a6!2sAir+Terjun+Yeh+Buah!8m2!3d-8.3393885!4d114.7504039!10e1!16s%2Fg%2F11g9nlfmzt!3m5!1s0x2dd17d7298ec6a85:0xa2feca286660c8a6!8m2!3d-8.3393885!4d114.7504039!16s%2Fg%2F11g9nlfmzt?entry=ttu',
#    'address': 'Yeh Embang Kauh, Kec. Mendoyo, Kabupaten Jembrana, Bali 82261',
#    'is_accessibility': 0,
#    'rating': 4.4,
#    'n_reviews': 23,
#    'price': 15000,
#    'category': 'Wisata Alam',
#    'description': 'Nestled in the middle of a lush tropical forest, Yeh Buah Waterfall offers a view of water rushing down into a natural pool below. This place is suitable for travelers who are looking for a nature adventure and enjoy the beauty of unspoiled nature.'}]}

# %%
def to_json(idx_recom):
    # decode all list

    # create json
    
    return None
